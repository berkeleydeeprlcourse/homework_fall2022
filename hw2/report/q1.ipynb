# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
q1_sb_no_rtg_dsa = np.loadtxt("q1_sb_no_rtg_dsa.txt")
q1_sb_rtg_dsa = np.loadtxt("q1_sb_rtg_dsa.txt")
q1_sb_rtg_na = np.loadtxt("q1_sb_rtg_na.txt")

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(20, 10))

fig.suptitle("PG - CartPole")
fig.supxlabel("Network with 2 Hidden Layers of size 64, 1K training steps per iteration, LR=0.001")


x = np.array(range(len(q1_sb_no_rtg_dsa)))

ax1.set_xlabel('Iteration')
ax1.set_ylabel('Mean Rewards(Validation)')
ax1.set_title("Iteration vs Mean Rewards for 1000 Steps")
ax1.set_xticks(np.arange(0, len(x) + 1, 10))

ax1.plot(x, q1_sb_no_rtg_dsa, label="q1_sb_no_rtg_dsa", color="red")
ax1.plot(x, q1_sb_rtg_dsa, label="q1_sb_rtg_dsa", color="black")
ax1.plot(x, q1_sb_rtg_na, label="q1_sb_rtg_na", color="green")

plt.legend()
plt.show()

# %%
import numpy as np
from scipy.stats import ttest_ind

print("q1_sb_no_rtg_dsa mean", np.mean(q1_sb_no_rtg_dsa))
print("q1_sb_rtg_dsa mean", np.mean(q1_sb_rtg_dsa))
print("q1_sb_rtg_na mean", np.mean(q1_sb_rtg_na))

print("q1_sb_no_rtg_dsa <-> q1_sb_rtg_dsa : same mean if p_value > 0.05 ", ttest_ind(q1_sb_no_rtg_dsa, q1_sb_rtg_dsa).pvalue)
print("q1_sb_rtg_dsa <-> q1_sb_rtg_na : same mean if p_value > 0.05 ", ttest_ind(q1_sb_rtg_dsa, q1_sb_rtg_na).pvalue)
# Out:
# q1_sb_no_rtg_dsa mean 86.4222952079773
# q1_sb_rtg_dsa mean 130.98664516448974
# q1_sb_rtg_na mean 133.72302099227906
# q1_sb_no_rtg_dsa <-> q1_sb_rtg_dsa : same mean if p_value > 0.05  3.0829269140808515e-08
# q1_sb_rtg_dsa <-> q1_sb_rtg_na : same mean if p_value > 0.05  0.7611728717242383

# %%
q1_lb_no_rtg_dsa = np.loadtxt("q1_lb_no_rtg_dsa.txt")
q1_lb_rtg_dsa = np.loadtxt("q1_lb_rtg_dsa.txt")
q1_lb_rtg_na = np.loadtxt("q1_lb_rtg_na.txt")

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(20, 10))

fig.suptitle("PG - CartPole")
fig.supxlabel("Network with 2 Hidden Layers of size 64, 5K training steps per iteration, LR=0.001")


x = np.array(range(len(q1_sb_no_rtg_dsa)))

ax1.set_xlabel('Iteration')
ax1.set_ylabel('Mean Rewards(Validation)')
ax1.set_title("Iteration vs Mean Rewards for 5000 Steps")
ax1.set_xticks(np.arange(0, len(x) + 1, 10))

ax1.plot(x, q1_lb_no_rtg_dsa, label="q1_lb_no_rtg_dsa",color="red")
ax1.plot(x, q1_lb_rtg_dsa, label="q1_lb_rtg_dsa",color="black")
ax1.plot(x, q1_lb_rtg_na, label="q1_lb_rtg_na",color="green")

plt.legend()
plt.show()

# %%
import numpy as np
from scipy.stats import ttest_ind

print("q1_lb_no_rtg_dsa mean", np.mean(q1_lb_no_rtg_dsa))
print("q1_lb_rtg_dsa mean", np.mean(q1_lb_rtg_dsa))
print("q1_lb_rtg_na mean", np.mean(q1_lb_rtg_na))

print("q1_lb_no_rtg_dsa <-> q1_lb_rtg_dsa : same mean if p_value > 0.05 ", ttest_ind(q1_lb_no_rtg_dsa, q1_lb_rtg_dsa).pvalue)
print("q1_lb_rtg_dsa <-> q1_lb_rtg_na : same mean if p_value > 0.05  ", ttest_ind(q1_lb_rtg_dsa, q1_lb_rtg_na).pvalue)
# Out:
# q1_lb_no_rtg_dsa mean 129.7941533279419
# q1_lb_rtg_dsa mean 149.94381664276122
# q1_lb_rtg_na mean 142.63789817810058
# q1_lb_no_rtg_dsa <-> q1_lb_rtg_dsa : same mean if p_value > 0.05  0.02113062178058201
# q1_lb_rtg_dsa <-> q1_lb_rtg_na : same mean if p_value > 0.05   0.4088605110317326
