# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
q2_b400_r005 = np.loadtxt("q2/q2_b<b400>_r<r0.005>.txt")
q2_b500_r005 = np.loadtxt("q2/q2_b<b500>_r<r0.005>.txt")

q2_b100_r01 = np.loadtxt("q2/q2_b<b100>_r<r0.01>.txt")
q2_b200_r01 = np.loadtxt("q2/q2_b<b200>_r<r0.01>.txt")

q2_b200_r02= np.loadtxt("q2/q2_b<b200>_r<r0.02>.txt")
q2_b300_r02= np.loadtxt("q2/q2_b<b300>_r<r0.02>.txt")

q2_b500_r03= np.loadtxt("q2/q2_b<b500>_r<r0.03>.txt")
q2_b600_r03= np.loadtxt("q2/q2_b<b600>_r<r0.03>.txt")

# %%
fig, ax = plt.subplots(6, 4, figsize=(20, 10))

x = np.array(range(len(q1_sb_no_rtg_dsa)))

ax[0,0].set_title("lr0.005")
ax[0,1].set_title("lr0.01")
ax[0,2].set_title("lr0.02")
ax[0,3].set_title("lr0.03")

ax[0,0].set_ylabel("b100")
ax[1,0].set_ylabel("b200")
ax[2,0].set_ylabel("b300")
ax[3,0].set_ylabel("b400")
ax[4,0].set_ylabel("b500")
ax[5,0].set_ylabel("b600")


ax[3,0].plot(x, q2_b400_r005)
ax[4,0].plot(x, q2_b500_r005)

ax[0,1].plot(x, q2_b100_r01)
ax[1,1].plot(x, q2_b200_r01)

ax[1,2].plot(x, q2_b200_r02)
ax[2,2].plot(x, q2_b300_r02)

ax[4,3].plot(x, q2_b500_r03)
ax[5,3].plot(x, q2_b600_r03)

plt.show()
