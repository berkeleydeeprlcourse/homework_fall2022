# %%
eval_arr_0 = np.loadtxt("../data/hw4_q6_cheetah_rlenl0_cheetah-cs285-v0_01-02-2023_23-25-17/eval.txt")
eval_arr_1 = np.loadtxt("../data/hw4_q6_cheetah_rlen1_cheetah-cs285-v0_01-02-2023_23-27-24/eval.txt")
eval_arr_10 = np.loadtxt("../data/hw4_q6_cheetah_rlen10_cheetah-cs285-v0_01-02-2023_23-32-10/eval.txt")

# %%
plt.figure(figsize=(15, 5), dpi=80)
plt.suptitle('Cheetah, train_steps_per_iter 1500, batch_size 5000, sac_batch_size 1500, ')

x = list(range(len(eval_arr_0[0])))

plt.subplot(121)
plt.title("Evaluation Average Return")

plt.plot(eval_arr_0[1], label="rollout_length 0, sac iter 1000")
plt.plot(eval_arr_1[1], label="rollout_length 1, sac iter 5000")
plt.plot(eval_arr_10[1], label="rollout_length 10, sac iter 5000")

plt.xticks(x)
plt.xlabel("Iteration")
plt.ylabel("Eval Average Return")

plt.grid()
plt.legend(loc='lower right')

plt.subplot(122)
plt.title("Iteration Duration")
plt.plot(eval_arr_0[3], label="rollout_length 0, sac iter 1000")
plt.plot(eval_arr_1[3], label="rollout_length 1, sac iter 5000")
plt.plot(eval_arr_10[3], label="rollout_length 10, sac iter 5000")
plt.xticks(x)
plt.xlabel("Iteration")
plt.ylabel("Iteration Duration(seconds)")

plt.grid()
plt.legend()
